# %%
qs = User.objects.all()

# %%
8qs
# Out:
#   File "/tmp/ipykernel_99076/1929576441.py", line 1
#     8qs
#      ^
# SyntaxError: invalid syntax

# %%
*qs
# Out:
#   File "/tmp/ipykernel_99076/218141884.py", line 1
#     *qs
#     ^
# SyntaxError: can't use starred expression here

# %%
a = *list(qs)
# Out:
#   File "/tmp/ipykernel_99076/1886960698.py", line 1
#     a = *list(qs)
#         ^
# SyntaxError: can't use starred expression here

# %%
a = *qs
# Out:
#   File "/tmp/ipykernel_99076/3969073589.py", line 1
#     a = *qs
#         ^
# SyntaxError: can't use starred expression here

# %%
def a(*args):
    print(args)

a(*qs)
# Out:
# (<User: david76@example.org>, <User: jamesrodriguez@example.org>, <User: medinajerry@example.org>, <User: josephgilbert@example.com>, <User: angelapatel@example.net>, <User: kingsteven@example.net>, <User: cnguyen@example.org>, <User: lbradley@example.com>, <User: gomezyvette@example.com>, <User: kelly18@example.net>, <User: desireeharmon@example.net>, <User: connergabriel@example.org>, <User: josephgarza@example.org>, <User: troy08@example.org>, <User: wsmith@example.com>, <User: guerraheather@example.org>, <User: athompson@example.net>, <User: tashaowens@example.org>, <User: uconley@example.com>, <User: friedmansteven@example.org>, <User: scottjackson@example.net>, <User: gregorydavis@example.org>, <User: sherry42@example.net>, <User: micheleclay@example.org>, <User: patrickjones@example.org>, <User: stephensanna@example.org>, <User: heather01@example.com>, <User: kaylee58@example.net>, <User: smithwilliam@example.org>, <User: mark92@example.net>, <User: hullbrandon@example.com>, <
# ...
